# %% [markdown]
# ## Predict the Customer Churn of a telcom company and find out the key drivers that lead to churn
#
# * Customer Churn is the percentage of customers who stop doing business with an entity.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
trainer = pd.read_csv('Telecom_Train.csv')
tester = pd.read_csv('Telecom_Test.csv')

# %%
trainer.shape
# Out:
# (3333, 21)

# %%
tester.shape
# Out:
# (1667, 21)

# %%
trainer.shape[0]/tester.shape[0]
# Out:
# 1.9994001199760048

# %%
trainer.head().T
# Out:
#                                            0              1              2  \
# Unnamed: 0                                 1              2              3
# state                                     KS             OH             NJ
# account_length                           128            107            137
# area_code                      area_code_415  area_code_415  area_code_415
# international_plan                        no             no             no
# voice_mail_plan                          yes            yes             no
# number_vmail_messages                     25             26              0
# total_day_minutes                      265.1          161.6          243.4
# total_day_calls                          110            123            114
# total_day_charge                       45.07          27.47          41.38
# total_eve_minutes                      197.4          195.5          121.2
# total_eve_calls                           99            103            110
# total_eve_charge                       16.78          16.62           10.3
# total_night_minutes                    244.7          254.4          162.6
# total_night_calls                         91            103            104
# total_night_charge                     11.01          11.45           7.32
# total_intl_minutes                      10.0           13.7           12.2
# total_intl_calls                           3              3              5
# total_intl_charge                        2.7            3.7           3.29
# number_customer_service_calls              1              1              0
# churn                                     no             no             no
#
#                                            3              4
# Unnamed: 0                                 4              5
# state                                     OH             OK
# account_length                            84             75
# area_code                      area_code_408  area_code_415
# international_plan                       yes            yes
# voice_mail_plan                           no             no
# number_vmail_messages                      0              0
# total_day_minutes                      299.4          166.7
# total_day_calls                           71            113
# total_day_charge                        50.9          28.34
# total_eve_minutes                       61.9          148.3
# total_eve_calls                           88            122
# total_eve_charge                        5.26          12.61
# total_night_minutes                    196.9          186.9
# total_night_calls                         89            121
# total_night_charge                      8.86           8.41
# total_intl_minutes                       6.6           10.1
# total_intl_calls                           7              3
# total_intl_charge                       1.78           2.73
# number_customer_service_calls              2              3
# churn                                     no             no

# %%
trainer.dtypes.sort_values()
# Out:
# Unnamed: 0                         int64
# account_length                     int64
# total_intl_calls                   int64
# number_vmail_messages              int64
# total_night_calls                  int64
# total_day_calls                    int64
# number_customer_service_calls      int64
# total_eve_calls                    int64
# total_intl_charge                float64
# total_intl_minutes               float64
# total_night_charge               float64
# total_night_minutes              float64
# total_eve_minutes                float64
# total_day_charge                 float64
# total_day_minutes                float64
# total_eve_charge                 float64
# voice_mail_plan                   object
# international_plan                object
# area_code                         object
# state                             object
# churn                             object
# dtype: object

# %%
trainer.isna().sum()
# Out:
# Unnamed: 0                       0
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
trainer.nunique().sort_values()
# Out:
# churn                               2
# international_plan                  2
# voice_mail_plan                     2
# area_code                           3
# number_customer_service_calls      10
# total_intl_calls                   21
# number_vmail_messages              46
# state                              51
# total_day_calls                   119
# total_night_calls                 120
# total_eve_calls                   123
# total_intl_charge                 162
# total_intl_minutes                162
# account_length                    212
# total_night_charge                933
# total_eve_charge                 1440
# total_night_minutes              1591
# total_eve_minutes                1611
# total_day_minutes                1667
# total_day_charge                 1667
# Unnamed: 0                       3333
# dtype: int64

# %%
tester.head().T
# Out:
#                                            0              1              2  \
# Unnamed: 0                                 1              2              3
# state                                     HI             MT             OH
# account_length                           101            137            103
# area_code                      area_code_510  area_code_510  area_code_408
# international_plan                        no             no             no
# voice_mail_plan                           no             no            yes
# number_vmail_messages                      0              0             29
# total_day_minutes                       70.9          223.6          294.7
# total_day_calls                          123             86             95
# total_day_charge                       12.05          38.01           50.1
# total_eve_minutes                      211.9          244.8          237.3
# total_eve_calls                           73            139            105
# total_eve_charge                       18.01          20.81          20.17
# total_night_minutes                    236.0           94.2          300.3
# total_night_calls                         73             81            127
# total_night_charge                     10.62           4.24          13.51
# total_intl_minutes                      10.6            9.5           13.7
# total_intl_calls                           3              7              6
# total_intl_charge                       2.86           2.57            3.7
# number_customer_service_calls              3              0              1
# churn                                     no             no             no
#
#                                            3              4
# Unnamed: 0                                 4              5
# state                                     NM             SC
# account_length                            99            108
# area_code                      area_code_415  area_code_415
# international_plan                        no             no
# voice_mail_plan                           no             no
# number_vmail_messages                      0              0
# total_day_minutes                      216.8          197.4
# total_day_calls                          123             78
# total_day_charge                       36.86          33.56
# total_eve_minutes                      126.4          124.0
# total_eve_calls                           88            101
# total_eve_charge                       10.74          10.54
# total_night_minutes                    220.6          204.5
# total_night_calls                         82            107
# total_night_charge                      9.93            9.2
# total_intl_minutes                      15.7            7.7
# total_intl_calls                           2              4
# total_intl_charge                       4.24           2.08
# number_customer_service_calls              1              2
# churn                                     no             no

# %%
tester.dtypes.sort_values()
# Out:
# Unnamed: 0                         int64
# account_length                     int64
# total_intl_calls                   int64
# number_vmail_messages              int64
# total_night_calls                  int64
# total_day_calls                    int64
# number_customer_service_calls      int64
# total_eve_calls                    int64
# total_intl_charge                float64
# total_intl_minutes               float64
# total_night_charge               float64
# total_night_minutes              float64
# total_eve_minutes                float64
# total_day_charge                 float64
# total_day_minutes                float64
# total_eve_charge                 float64
# voice_mail_plan                   object
# international_plan                object
# area_code                         object
# state                             object
# churn                             object
# dtype: object

# %%
tester.isna().sum()
# Out:
# Unnamed: 0                       0
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
tester.nunique().sort_values()
# Out:
# churn                               2
# international_plan                  2
# voice_mail_plan                     2
# area_code                           3
# number_customer_service_calls       8
# total_intl_calls                   19
# number_vmail_messages              41
# state                              51
# total_day_calls                   109
# total_eve_calls                   109
# total_night_calls                 121
# total_intl_charge                 148
# total_intl_minutes                148
# account_length                    198
# total_night_charge                743
# total_eve_charge                  993
# total_eve_minutes                1088
# total_night_minutes              1093
# total_day_charge                 1098
# total_day_minutes                1098
# Unnamed: 0                       1667
# dtype: int64

# %%
df_train = trainer.copy()
df_test = tester.copy()

# %%
df_train = df_train.drop('Unnamed: 0', axis=1)
df_test = df_test.drop('Unnamed: 0', axis=1)

# %%
df_train.shape
# Out:
# (3333, 20)
