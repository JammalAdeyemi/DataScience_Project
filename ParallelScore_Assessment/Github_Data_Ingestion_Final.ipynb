# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests

# %%
load_dotenv()

USERNAME = os.getenv("Jamma7")
TOKEN = os.getenv("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")

# %%
total_github_users = []
total_users_info = []

# %%
def fetch_users_from_github(page):
    users = requests.get("https://api.github.com/search/users?accept=application/vnd.github.v3+json&q=Machine Learning location:Lagos location:Rwanda location:Nigeria&per_page=100&page="+str(page))
    return users.json()

def fetch_user_from_github(url):
    user = requests.get(url)
    return user.json()

# %%
def get_all_users(page):
    global total_github_users
    users = fetch_users_from_github(page)
    total_github_users += users['items']
    no_per_page = 100
    no_of_users = users['total_count']
    amount = (no_of_users // no_per_page) + 1
    if(page == amount):
        return 0
    else:
        get_all_users(page + 1)

# %%
get_all_users(1)
len(total_github_users)
# Out:
# 502

# %%
# 9:50
for a in range(120,180):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 10:56
for a in range(180,240):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 11:57
for a in range(240,300):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 12:58
for a in range(300, 360):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 13:59
for a in range(360,420):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 15:00
for a in range(420, 480):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
# 16:01
for a in range(480, 502):
    user = fetch_user_from_github(total_github_users[a]['url'])
    total_users_info.append(user)

# %%
total_users_info = total_users_info[:502]

# %%
len(total_users_info)
# Out:
# 502

# %%
total_users_info
# Out:
# [{'login': 'Nyandwi',
#   'id': 52796597,
#   'node_id': 'MDQ6VXNlcjUyNzk2NTk3',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/52796597?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Nyandwi',
#   'html_url': 'https://github.com/Nyandwi',
#   'followers_url': 'https://api.github.com/users/Nyandwi/followers',
#   'following_url': 'https://api.github.com/users/Nyandwi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Nyandwi/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Nyandwi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Nyandwi/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Nyandwi/orgs',
#   'repos_url': 'https://api.github.com/users/Nyandwi/repos',
#   'events_url': 'https://api.github.com/users/Nyandwi/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Nyandwi/received_events',
#   'type': 'User',
# ...

# %%
user = pd.DataFrame(total_users_info)
user.head()
# Out:
#                                                                      0  \
# login                                                          Nyandwi
# id                                                            52796597
# node_id                                           MDQ6VXNlcjUyNzk2NTk3
# avatar_url           https://avatars.githubusercontent.com/u/527965...
# gravatar_id
# url                               https://api.github.com/users/Nyandwi
# html_url                                    https://github.com/Nyandwi
# followers_url           https://api.github.com/users/Nyandwi/followers
# following_url        https://api.github.com/users/Nyandwi/following...
# gists_url            https://api.github.com/users/Nyandwi/gists{/gi...
# starred_url          https://api.github.com/users/Nyandwi/starred{/...
# subscriptions_url    https://api.github.com/users/Nyandwi/subscript...
# organizations_url            https://api.github.com/users/Nyandwi/orgs
# ...

# %%
user_df = pd.DataFrame(total_users_info)
user_df.head()
# Out:
#             login        id               node_id  \
# 0         Nyandwi  52796597  MDQ6VXNlcjUyNzk2NTk3
# 1        EdemGold  78963277  MDQ6VXNlcjc4OTYzMjc3
# 2       korecodes  15997058  MDQ6VXNlcjE1OTk3MDU4
# 3  philipszdavido  25048922  MDQ6VXNlcjI1MDQ4OTIy
# 4   Micah-Shallom  64049432  MDQ6VXNlcjY0MDQ5NDMy
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/527965...
# 1  https://avatars.githubusercontent.com/u/789632...
# 2  https://avatars.githubusercontent.com/u/159970...
# 3  https://avatars.githubusercontent.com/u/250489...
# 4  https://avatars.githubusercontent.com/u/640494...
#
#                                            url  \
# 0         https://api.github.com/users/Nyandwi
# 1        https://api.github.com/users/EdemGold
# 2       https://api.github.com/users/korecodes
# 3  https://api.github.com/users/philipszdavido
# 4   https://api.github.com/users/Micah-Shallom
#
# ...

# %%
user.shape
# Out:
# (480, 32)

# %%
user_df.shape
# Out:
# (502, 32)

# %%
user
# Out:
#                 login        id               node_id  \
# 0             Nyandwi  52796597  MDQ6VXNlcjUyNzk2NTk3
# 1            EdemGold  78963277  MDQ6VXNlcjc4OTYzMjc3
# 2           korecodes  15997058  MDQ6VXNlcjE1OTk3MDU4
# 3      philipszdavido  25048922  MDQ6VXNlcjI1MDQ4OTIy
# 4       Micah-Shallom  64049432  MDQ6VXNlcjY0MDQ5NDMy
# ..                ...       ...                   ...
# 415        eghogho574  70743507  MDQ6VXNlcjcwNzQzNTA3
# 416  OfficialOakinlua  23633338  MDQ6VXNlcjIzNjMzMzM4
# 417          mosesjnr  66074433  MDQ6VXNlcjY2MDc0NDMz
# 418    Samuel-Effiong  45684363  MDQ6VXNlcjQ1Njg0MzYz
# 419       akpodiogaga  97741705          U_kgDOBdNriQ
#
#                                             avatar_url gravatar_id  \
# 0    https://avatars.githubusercontent.com/u/527965...
# 1    https://avatars.githubusercontent.com/u/789632...
# 2    https://avatars.githubusercontent.com/u/159970...
# 3    https://avatars.githubusercontent.com/u/250489...
# ...

# %%
user_df
# Out:
#               login        id               node_id  \
# 0           Nyandwi  52796597  MDQ6VXNlcjUyNzk2NTk3
# 1          EdemGold  78963277  MDQ6VXNlcjc4OTYzMjc3
# 2         korecodes  15997058  MDQ6VXNlcjE1OTk3MDU4
# 3    philipszdavido  25048922  MDQ6VXNlcjI1MDQ4OTIy
# 4     Micah-Shallom  64049432  MDQ6VXNlcjY0MDQ5NDMy
# ..              ...       ...                   ...
# 497          dasjar  52583544  MDQ6VXNlcjUyNTgzNTQ0
# 498     Jargo192000  40345495  MDQ6VXNlcjQwMzQ1NDk1
# 499         Caycode  63520605  MDQ6VXNlcjYzNTIwNjA1
# 500         bengafa  33180197  MDQ6VXNlcjMzMTgwMTk3
# 501          dasjar  52583544  MDQ6VXNlcjUyNTgzNTQ0
#
#                                             avatar_url gravatar_id  \
# 0    https://avatars.githubusercontent.com/u/527965...
# 1    https://avatars.githubusercontent.com/u/789632...
# 2    https://avatars.githubusercontent.com/u/159970...
# 3    https://avatars.githubusercontent.com/u/250489...
# ...

# %%
df = user[['name', 'login', 'bio', 'blog', 'company', 'email', 'followers', 'following', 'id', 'url', 'location']]
df.T
# Out:
#                                             0    \
# name                       Jean de Dieu Nyandwi
# login                                   Nyandwi
# bio          Machine Learning & Computer Vision
# blog                  https://jeande.medium.com
# company                                    None
# email                                      None
# followers                                   226
# following                                    75
# id                                     52796597
# url        https://api.github.com/users/Nyandwi
# location                         Kigali, Rwanda
#
#                                                 1    \
# name                                      Edem Gold
# login                                      EdemGold
# bio        Blockchain, Applied Machine Learning\r\n
# blog                         https://edemgold.blog/
# company                                        None
# email                                          None
# ...

# %%
final_df = user_df[['name', 'login', 'bio', 'blog', 'company', 'email', 'followers', 'following', 'id', 'url', 'location']]
final_df.T
# Out:
#                                             0    \
# name                       Jean de Dieu Nyandwi
# login                                   Nyandwi
# bio          Machine Learning & Computer Vision
# blog                  https://jeande.medium.com
# company                                    None
# email                                      None
# followers                                   226
# following                                    75
# id                                     52796597
# url        https://api.github.com/users/Nyandwi
# location                         Kigali, Rwanda
#
#                                                 1    \
# name                                      Edem Gold
# login                                      EdemGold
# bio        Blockchain, Applied Machine Learning\r\n
# blog                         https://edemgold.blog/
# company                                        None
# email                                          None
# ...

# %%
df.to_csv('Github_ML_Users.csv', sep=',', encoding='utf-8', index=False)
