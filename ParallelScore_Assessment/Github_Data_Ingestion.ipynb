# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests

# %%
load_dotenv()

USERNAME = os.getenv("Jamma7")
TOKEN = os.getenv("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")

# %%
total_github_users = []
total_users_info = []

# %%
def fetch_users_from_github(page):
    users = requests.get("https://api.github.com/search/users?accept=application/vnd.github.v3+json&q=Machine Learning location:Lagos location:Rwanda location:Nigeria&per_page=100&page="+str(page))
    return users.json()

def fetch_user_from_github(url):
    user = requests.get(url)
    return user.json()

# %%
def get_all_users(page):
    global total_github_users
    users = fetch_users_from_github(page)
    total_github_users += users['items']
    no_per_page = 100
    no_of_users = users['total_count']
    amount = (no_of_users // no_per_page) + 1
    if(page == amount):
        return 0
    else:
        get_all_users(page + 1)

# %%
get_all_users(1)
for github_user in total_github_users:
    user = fetch_user_from_github(github_user['url'])
    total_users_info.append(user)

# %%
total_github_users[-1]
# Out:
# {'login': 'coekoh',
#  'id': 73580470,
#  'node_id': 'MDQ6VXNlcjczNTgwNDcw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/73580470?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/coekoh',
#  'html_url': 'https://github.com/coekoh',
#  'followers_url': 'https://api.github.com/users/coekoh/followers',
#  'following_url': 'https://api.github.com/users/coekoh/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/coekoh/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/coekoh/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/coekoh/subscriptions',
#  'organizations_url': 'https://api.github.com/users/coekoh/orgs',
#  'repos_url': 'https://api.github.com/users/coekoh/repos',
#  'events_url': 'https://api.github.com/users/coekoh/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/coekoh/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'score': 1.0}

# %%
total_users_info[-1]
# Out:
# {'message': "API rate limit exceeded for 154.118.24.185. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}

# %%
user_df = pd.DataFrame(total_users_info)
user_df.head().T
# Out:
#                                                                      0  \
# login                                                          Nyandwi
# id                                                          52796597.0
# node_id                                           MDQ6VXNlcjUyNzk2NTk3
# avatar_url           https://avatars.githubusercontent.com/u/527965...
# gravatar_id
# url                               https://api.github.com/users/Nyandwi
# html_url                                    https://github.com/Nyandwi
# followers_url           https://api.github.com/users/Nyandwi/followers
# following_url        https://api.github.com/users/Nyandwi/following...
# gists_url            https://api.github.com/users/Nyandwi/gists{/gi...
# starred_url          https://api.github.com/users/Nyandwi/starred{/...
# subscriptions_url    https://api.github.com/users/Nyandwi/subscript...
# organizations_url            https://api.github.com/users/Nyandwi/orgs
# repos_url                   https://api.github.com/users/Nyandwi/repos
# events_url           https://api.github.com/users/Nyandwi/events{/p...
# received_events_url  https://api.github.com/users/Nyandwi/received_...
# type                                                              User
# site_admin                                                       False
# name                                              Jean de Dieu Nyandwi
# company                                                           None
# blog                                         https://jeande.medium.com
# location                                                Kigali, Rwanda
# email                                                              NaN
# hireable                                                          None
# bio                       Machine Learning & Computer Vision Scientist
# twitter_username                                              Jeande_d
# public_repos                                                      22.0
# public_gists                                                       0.0
# followers                                                        193.0
# following                                                         61.0
# created_at                                        2019-07-11T17:12:05Z
# updated_at                                        2021-12-24T15:45:44Z
# message                                                            NaN
# documentation_url                                                  NaN
#
#                                                                      1  \
# login                                                     eniolasonowo
# id                                                          60398534.0
# node_id                                           MDQ6VXNlcjYwMzk4NTM0
# avatar_url           https://avatars.githubusercontent.com/u/603985...
# gravatar_id
# url                          https://api.github.com/users/eniolasonowo
# html_url                               https://github.com/eniolasonowo
# followers_url        https://api.github.com/users/eniolasonowo/foll...
# following_url        https://api.github.com/users/eniolasonowo/foll...
# gists_url            https://api.github.com/users/eniolasonowo/gist...
# starred_url          https://api.github.com/users/eniolasonowo/star...
# subscriptions_url    https://api.github.com/users/eniolasonowo/subs...
# organizations_url       https://api.github.com/users/eniolasonowo/orgs
# repos_url              https://api.github.com/users/eniolasonowo/repos
# events_url           https://api.github.com/users/eniolasonowo/even...
# received_events_url  https://api.github.com/users/eniolasonowo/rece...
# type                                                              User
# site_admin                                                       False
# name                                                     eniola sonowo
# company                                          @team-studentxchange
# blog
# location                                                       Nigeria
# email                                                              NaN
# hireable                                                          None
# bio                          BlockchainDev | Machine Learning Engineer
# twitter_username                                          eniolasonowo
# public_repos                                                      41.0
# public_gists                                                       0.0
# followers                                                         58.0
# following                                                        104.0
# created_at                                        2020-01-28T16:14:33Z
# updated_at                                        2022-01-10T17:44:16Z
# message                                                            NaN
# documentation_url                                                  NaN
#
#                                                                      2  \
# login                                                         EdemGold
# id                                                          78963277.0
# node_id                                           MDQ6VXNlcjc4OTYzMjc3
# avatar_url           https://avatars.githubusercontent.com/u/789632...
# gravatar_id
# url                              https://api.github.com/users/EdemGold
# html_url                                   https://github.com/EdemGold
# followers_url          https://api.github.com/users/EdemGold/followers
# following_url        https://api.github.com/users/EdemGold/followin...
# gists_url            https://api.github.com/users/EdemGold/gists{/g...
# starred_url          https://api.github.com/users/EdemGold/starred{...
# subscriptions_url    https://api.github.com/users/EdemGold/subscrip...
# organizations_url           https://api.github.com/users/EdemGold/orgs
# repos_url                  https://api.github.com/users/EdemGold/repos
# events_url           https://api.github.com/users/EdemGold/events{/...
# received_events_url  https://api.github.com/users/EdemGold/received...
# type                                                              User
# site_admin                                                       False
# name                                                         Edem Gold
# company                                                           None
# blog                                            https://edemgold.blog/
# location                                               calabar,Nigeria
# email                                                              NaN
# hireable                                                          True
# bio                        Technophile, Machine Learning Engineer.\r\n
# twitter_username                                             EdemGold1
# public_repos                                                      62.0
# public_gists                                                       1.0
# followers                                                         32.0
# following                                                         84.0
# created_at                                        2021-02-12T12:37:34Z
# updated_at                                        2022-01-10T01:54:44Z
# message                                                            NaN
# documentation_url                                                  NaN
#
#                                                                      3  \
# login                                                          JUGG097
# id                                                          56544415.0
# node_id                                           MDQ6VXNlcjU2NTQ0NDE1
# avatar_url           https://avatars.githubusercontent.com/u/565444...
# gravatar_id
# url                               https://api.github.com/users/JUGG097
# html_url                                    https://github.com/JUGG097
# followers_url           https://api.github.com/users/JUGG097/followers
# following_url        https://api.github.com/users/JUGG097/following...
# gists_url            https://api.github.com/users/JUGG097/gists{/gi...
# starred_url          https://api.github.com/users/JUGG097/starred{/...
# subscriptions_url    https://api.github.com/users/JUGG097/subscript...
# organizations_url            https://api.github.com/users/JUGG097/orgs
# repos_url                   https://api.github.com/users/JUGG097/repos
# events_url           https://api.github.com/users/JUGG097/events{/p...
# received_events_url  https://api.github.com/users/JUGG097/received_...
# type                                                              User
# site_admin                                                       False
# name                                                  Adeoluwa Adeboye
# company                                                           None
# blog
# location                                                       Nigeria
# email                                                              NaN
# hireable                                                          True
# bio                  Engineering | Machine Learning | Web Developme...
# twitter_username                                             adeneye97
# public_repos                                                      32.0
# public_gists                                                       0.0
# followers                                                         52.0
# following                                                         67.0
# created_at                                        2019-10-14T11:49:07Z
# updated_at                                        2021-11-22T14:45:36Z
# message                                                            NaN
# documentation_url                                                  NaN
#
#                                                                      4
# login                                                   philipszdavido
# id                                                          25048922.0
# node_id                                           MDQ6VXNlcjI1MDQ4OTIy
# avatar_url           https://avatars.githubusercontent.com/u/250489...
# gravatar_id
# url                        https://api.github.com/users/philipszdavido
# html_url                             https://github.com/philipszdavido
# followers_url        https://api.github.com/users/philipszdavido/fo...
# following_url        https://api.github.com/users/philipszdavido/fo...
# gists_url            https://api.github.com/users/philipszdavido/gi...
# starred_url          https://api.github.com/users/philipszdavido/st...
# subscriptions_url    https://api.github.com/users/philipszdavido/su...
# organizations_url     https://api.github.com/users/philipszdavido/orgs
# repos_url            https://api.github.com/users/philipszdavido/repos
# events_url           https://api.github.com/users/philipszdavido/ev...
# received_events_url  https://api.github.com/users/philipszdavido/re...
# type                                                              User
# site_admin                                                       False
# name                                                    Chidume Nnamdi
# company                                                           None
# blog                                           twitter.com/ngArchangel
# location                                              Anambra, Nigeria
# email                                                              NaN
# hireable                                                          True
# bio                  JavaScript Ninja | Angular Archangel | Machine...
# twitter_username                                                  None
# public_repos                                                     269.0
# public_gists                                                      75.0
# followers                                                         92.0
# following                                                         68.0
# created_at                                        2017-01-11T05:12:54Z
# updated_at                                        2021-11-20T20:10:35Z
# message                                                            NaN
# documentation_url                                                  NaN

# %% [markdown]
# The expected data points to be ingested or seen in the data frame include
# name,
# login/username, Bio,
# Blog, Company, email,
# followers(count of followers),
# following(count of following),
# id, url, and location.)

# %%
df = user_df[['name', 'login', 'bio', 'blog', 'company', 'email', 'followers', 'following', 'id', 'url', 'location']]

# %%
df
# Out:
#                      name           login  \
# 0    Jean de Dieu Nyandwi         Nyandwi
# 1           eniola sonowo    eniolasonowo
# 2               Edem Gold        EdemGold
# 3        Adeoluwa Adeboye         JUGG097
# 4          Chidume Nnamdi  philipszdavido
# ..                    ...             ...
# 489                   NaN             NaN
# 490                   NaN             NaN
# 491                   NaN             NaN
# 492                   NaN             NaN
# 493                   NaN             NaN
#
#                                                    bio  \
# 0         Machine Learning & Computer Vision Scientist
# 1            BlockchainDev | Machine Learning Engineer
# 2          Technophile, Machine Learning Engineer.\r\n
# 3    Engineering | Machine Learning | Web Developme...
# 4    JavaScript Ninja | Angular Archangel | Machine...
# ..                                                 ...
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
# 493                                                NaN
#
#                           blog                company  email  followers  \
# 0    https://jeande.medium.com                   None    NaN      193.0
# 1                               @team-studentxchange     NaN       58.0
# 2       https://edemgold.blog/                   None    NaN       32.0
# 3                                                None    NaN       52.0
# 4      twitter.com/ngArchangel                   None    NaN       92.0
# ..                         ...                    ...    ...        ...
# 489                        NaN                    NaN    NaN        NaN
# 490                        NaN                    NaN    NaN        NaN
# 491                        NaN                    NaN    NaN        NaN
# 492                        NaN                    NaN    NaN        NaN
# 493                        NaN                    NaN    NaN        NaN
#
#      following          id                                          url  \
# 0         61.0  52796597.0         https://api.github.com/users/Nyandwi
# 1        104.0  60398534.0    https://api.github.com/users/eniolasonowo
# 2         84.0  78963277.0        https://api.github.com/users/EdemGold
# 3         67.0  56544415.0         https://api.github.com/users/JUGG097
# 4         68.0  25048922.0  https://api.github.com/users/philipszdavido
# ..         ...         ...                                          ...
# 489        NaN         NaN                                          NaN
# 490        NaN         NaN                                          NaN
# 491        NaN         NaN                                          NaN
# 492        NaN         NaN                                          NaN
# 493        NaN         NaN                                          NaN
#
#              location
# 0      Kigali, Rwanda
# 1             Nigeria
# 2     calabar,Nigeria
# 3             Nigeria
# 4    Anambra, Nigeria
# ..                ...
# 489               NaN
# 490               NaN
# 491               NaN
# 492               NaN
# 493               NaN
#
# [494 rows x 11 columns]

# %%
#df.to_csv('Github_Users.csv', sep=',', encoding='utf-8', index=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-12-15301f902527> in <module>
# ----> 1 df.to_csv('Github_Users.csv', sep=',', encoding='utf-8', index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'Github_Users.csv'

# %%
df.isna().sum()
