# %% [markdown]
# #  Predicting the Sale Price of Houses using Machine Learning
#
#
# ## 1. Problem defition
#
# > This project aims to build a machine learning model that will give the best future sales prediction of homes and improve the log error i.e. the error due to the difference between the actual and the predicted home values.
#
# ## 2. Data
# The data is downloaded from the Kaggle Bluebook for Zillow price competition: https://www.kaggle.com/c/zillow-prize-1/data
#
# There are 3 main datasets:
#
# * properties_2016.csv - all the properties with their home features for 2016.
# * properties_2017.csv - all the properties with their home features for 2017 (released on 10/2/2017)
# * train_2016.csv - the training set with transactions from 1/1/2016 to 12/31/2016
# * train_2017.csv - the training set with transactions from 1/1/2017 to 9/15/2017 (released on 10/2/2017)
#
# ## 3. Evaluation
# The evaluation metric for this competition is the MAE (Mean Absolute Error) between the predicted log error and the actual log error.
#
# For more on the evaluation of this project check: https://www.kaggle.com/c/zillow-prize-1/overview/evaluation
#
# ## 4. Features
# Kaggle provides a data dictionary detailing all of the features of the dataset.
#
# There are two datasets available –
#
# * train_2016 – This dataset consists of the target variable i.e., the logerror
# * properties_2016 – Contents all the features related to the property/home.
#
#
# There are around 60 attributes in the dataset on basis of which the model can be built.
#
# Some of the important features amongst them are as follows:
#
# * train_2016:
#     1. parcelid - Unique identification for every parcel
#     2. transactiondate - The date on which the home was sold
#     3. logerror - The residual between the actual and the predicted sale price of homes. (Target Array)
#
#
# * properties_2016:
#     1. parcelid - Unique identification for every parcel (common in both the datasets)
#     2. bathroomcnt - Total number of bathrooms in the house
#     3. bedroomcnt - Total number of bedrooms in the house
#     4. buildingqualitytypeid - This gives the quality assessment of the building ranging from best to worst.
#     5. finishedsqaurefeet12 - Finished living area of the house.
#     6. fips - This stand for Federal Information Processing Standard code (for more detail regarding this check:https://en.wikipedia.org/wiki/FIPS_county_code
#     7. latitude & longitude - longitude and latitude of the home location
#     8. propertylandusetypeid - This gives the type of land the property is zoned for.
#     9regionidcity - The city in which the property is situated.
# regionidcounty - The county where the property is situated.
# regionidzip - This provides the zip code for the location of the property.
# taxamount - Property tax for each assessment year

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.simplefilter(action='ignore')
pd.set_option('display.max_columns', None)

# %%
properties_2016 = pd.read_csv("../../../../../House_price_regression_data/properties_2016.csv")
train_2016 = pd.read_csv("../../../../../House_price_regression_data/train_2016_v2.csv")

# %%
properties_2016.shape
# Out:
# (2985217, 58)

# %%
train_2016.shape
# Out:
# (90275, 3)

# %%
properties_2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# ...

# %%
train_2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
final_df = pd.merge(properties_2016, train_2016, how='inner', on='parcelid')
final_df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# ...

# %%
final_df.shape
# Out:
# (90275, 60)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90275 entries, 0 to 90274
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      90275 non-null  int64
#  1   airconditioningtypeid         28781 non-null  float64
#  2   architecturalstyletypeid      261 non-null    float64
#  3   basementsqft                  43 non-null     float64
#  4   bathroomcnt                   90275 non-null  float64
#  5   bedroomcnt                    90275 non-null  float64
#  6   buildingclasstypeid           16 non-null     float64
#  7   buildingqualitytypeid         57364 non-null  float64
#  8   calculatedbathnbr             89093 non-null  float64
#  9   decktypeid                    658 non-null    float64
#  10  finishedfloor1squarefeet      6856 non-null   float64
#  11  calculatedfinishedsquarefeet  89614 non-null  float64
# ...

# %%
categorical = final_df.select_dtypes(include='object').columns
categorical
# Out:
# Index(['hashottuborspa', 'propertycountylandusecode', 'propertyzoningdesc',
#        'fireplaceflag', 'taxdelinquencyflag', 'transactiondate'],
#       dtype='object')

# %%
final_df.isnull().sum()
# Out:
# parcelid                            0
# airconditioningtypeid           61494
# architecturalstyletypeid        90014
# basementsqft                    90232
# bathroomcnt                         0
# bedroomcnt                          0
# buildingclasstypeid             90259
# buildingqualitytypeid           32911
# calculatedbathnbr                1182
# decktypeid                      89617
# finishedfloor1squarefeet        83419
# calculatedfinishedsquarefeet      661
# finishedsquarefeet12             4679
# finishedsquarefeet13            90242
# finishedsquarefeet15            86711
# finishedsquarefeet50            83419
# finishedsquarefeet6             89854
# fips                                0
# fireplacecnt                    80668
# fullbathcnt                      1182
# garagecarcnt                    60338
# garagetotalsqft                 60338
# hashottuborspa                  87910
# heatingorsystemtypeid           34195
# latitude                            0
# ...

# %%
final_df.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  9.027500e+04           28781.000000                261.000000
# mean   1.298466e+07               1.816372                  7.229885
# std    2.504510e+06               2.974168                  2.716196
# min    1.071174e+07               1.000000                  2.000000
# 25%    1.155950e+07               1.000000                  7.000000
# 50%    1.254734e+07               1.000000                  7.000000
# 75%    1.422755e+07               1.000000                  7.000000
# max    1.629608e+08              13.000000                 21.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid  \
# count     43.000000  90275.000000  90275.000000                 16.0
# mean     713.581395      2.279474      3.031869                  4.0
# std      437.434198      1.004271      1.156436                  0.0
# ...

# %% [markdown]
# ### Dealing with the missing values:

# %%
mis_val = [var for var in final_df.columns if final_df[var].isnull().sum()>0]

final_df[mis_val].isnull().sum()
# Out:
# airconditioningtypeid           61494
# architecturalstyletypeid        90014
# basementsqft                    90232
# buildingclasstypeid             90259
# buildingqualitytypeid           32911
# calculatedbathnbr                1182
# decktypeid                      89617
# finishedfloor1squarefeet        83419
# calculatedfinishedsquarefeet      661
# finishedsquarefeet12             4679
# finishedsquarefeet13            90242
# finishedsquarefeet15            86711
# finishedsquarefeet50            83419
# finishedsquarefeet6             89854
# fireplacecnt                    80668
# fullbathcnt                      1182
# garagecarcnt                    60338
# garagetotalsqft                 60338
# hashottuborspa                  87910
# heatingorsystemtypeid           34195
# lotsizesquarefeet               10150
# poolcnt                         72374
# poolsizesum                     89306
# pooltypeid10                    89114
# pooltypeid2                     89071
# ...

# %%
# Relationship between missing values and target_variables(log error) :
def analyze_missing_values(df, var):
    new_df = df.copy()
    new_df[var] = np.where(new_df[var].isnull(),1,0)
    new_df.groupby(var)['logerror'].median().plot.bar()
    plt.title(var)
    plt.show()
    
for var in mis_val:
    analyze_missing_values(final_df, var)

# %%
print("Total no of variables with missing value in the dataset: ", len(mis_val))
# Out:
# Total no of variables with missing value in the dataset:  47

# %%
num_vars = [var for var in final_df.columns if final_df[var].dtypes!= 'O']
print("Total no of numerical variables in the dataset: ", len(num_vars))
# Out:
# Total no of numerical variables in the dataset:  54

# %%
final_df[num_vars].columns
# Out:
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
# ...

# %%
cat_vars = [var for var in final_df.columns if final_df[var].dtypes== 'O']
print("Total no of categorical variables in the dataset: ", len(cat_vars))
# Out:
# Total no of categorical variables in the dataset:  6

# %%
final_df[cat_vars].columns
# Out:
# Index(['hashottuborspa', 'propertycountylandusecode', 'propertyzoningdesc',
#        'fireplaceflag', 'taxdelinquencyflag', 'transactiondate'],
#       dtype='object')

# %%
# Cardinality of Categorical variables:

for var in cat_vars:
    print(var, len(final_df[var].unique()), " Categories")
# Out:
# hashottuborspa 2  Categories
# propertycountylandusecode 78  Categories
# propertyzoningdesc 1997  Categories
# fireplaceflag 2  Categories
# taxdelinquencyflag 2  Categories
# transactiondate 352  Categories

# %%
# Temporal variables:
year_var = [var for var in num_vars if 'Yr' in var or 'year' in var ]
len(year_var), year_var
# Out:
# (3, ['yearbuilt', 'assessmentyear', 'taxdelinquencyyear'])

# %%
# Relationship between temporal variables and log error:

#calculate difference between year variable and year the house was sold
final_df[var] = final_df['assessmentyear'] - final_df['yearbuilt']  

plt.scatter(final_df[var],final_df['logerror'])
plt.xlabel('Year Difference')
plt.ylabel('logerror')
plt.show()

# %%
# Discrete variables:

discrete_vars = [var for var in num_vars if len(final_df[var].unique())<20]
print('No of discrete variables : ', len(discrete_vars))
# Out:
# No of discrete variables :  26

# %%
final_df[discrete_vars].columns
# Out:
# Index(['airconditioningtypeid', 'architecturalstyletypeid', 'bedroomcnt',
#        'buildingclasstypeid', 'buildingqualitytypeid', 'decktypeid',
#        'finishedsquarefeet13', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'heatingorsystemtypeid', 'poolcnt', 'pooltypeid10',
#        'pooltypeid2', 'pooltypeid7', 'propertylandusetypeid', 'regionidcounty',
#        'roomcnt', 'storytypeid', 'threequarterbathnbr',
#        'typeconstructiontypeid', 'unitcnt', 'numberofstories',
#        'assessmentyear', 'taxdelinquencyyear'],
#       dtype='object')

# %%
# Continuous variables:
cont_vars = [var for var in num_vars if var not in discrete_vars+year_var]
print('No of continuous variables : ', len(cont_vars))
# Out:
# No of continuous variables :  27

# %%
def analyze_cont_vars(df,var):
    
    new_df = final_df.copy()
    new_df[var].hist(bins=20)
    plt.xlabel(var)
    plt.ylabel('Count')
    plt.title('Variation of '+ var)
    plt.show()
    
for var in cont_vars:
    analyze_cont_vars(final_df,var)

# %% [markdown]
# Some of the variables are not normally distributed.
#
# Let's evaluate if a logarithmic transformation of the variables returns values that follow a normal distribution:

# %%
def analyze_log_variation(df,var):
    
    new_df = df.copy()
    if 0 in new_df[var].unique():
        pass
    else:
        #log Transformation of variables
        new_df[var] = np.log(new_df[var])
        new_df[var].hist(bins=20)
        plt.xlabel(var)
        plt.ylabel('Count')
        plt.title('Logarithmic Variation of '+ var)
        plt.show()
        
for var in cont_vars:
    analyze_log_variation(final_df,var)

# %% [markdown]
# We see that we get a better spread of the values for only few variables when we use the logarithmic transformation.

# %%
# Analyzing Outliers:

def analyze_outliers(df,var):
    
    df = df.copy()
    
    if 0 in df[var].unique():
        pass
    else:
        df[var] = np.log(df[var])
        df.boxplot(column=var)
        plt.show()
        
for var in cont_vars:
    analyze_outliers(final_df,var)

# %% [markdown]
# Anything beyond the max and min line are classified as outliers

# %% [markdown]
# ## Feature Engineering
# In the following cells, we will engineer / pre-process the variables of the House Price Dataset from Kaggle. We will engineer the variables so that we tackle:
#
# * Duplicate check
# * Missing values
# * Temporal variables
# * Selective transformation of incorrectly scaled values
# * Standarise the values of all variables to the same range (Standardization)
# * Encoding of Categorical variables
# * Forming new meaningful features if needed
# * Dropping redundant columns
# * Multi-Colinearity check and removal
# * Outlier check and removal

# %%
import math as mat
from scipy import stats
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
final_df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# ...

# %% [markdown]
# ### Duplicate entry check

# %%
duplicate = final_df[final_df.duplicated("parcelid")]
duplicate.shape
# Out:
# (125, 60)

# %% [markdown]
# We observe that there are 125 rows of duplicate data with respect to the same parcelid. Hence, we will go ahead and drop those.

# %%
final_df.drop_duplicates(subset="parcelid", keep="first", inplace=True)
final_df.shape
# Out:
# (90150, 60)

# %% [markdown]
# ### Missing Values

# %%
mis_val = [var for var in final_df.columns if final_df[var].isnull().sum()>0]
final_df[mis_val].isnull().sum()
# Out:
# airconditioningtypeid           61402
# architecturalstyletypeid        89890
# basementsqft                    90107
# buildingclasstypeid             90134
# buildingqualitytypeid           32866
# calculatedbathnbr                1176
# decktypeid                      89492
# finishedfloor1squarefeet        83300
# calculatedfinishedsquarefeet      658
# finishedsquarefeet12             4665
# finishedsquarefeet13            90117
# finishedsquarefeet15            86595
# finishedsquarefeet50            83300
# finishedsquarefeet6             89731
# fireplacecnt                    80553
# fullbathcnt                      1176
# garagecarcnt                    60253
# garagetotalsqft                 60253
# hashottuborspa                  87787
# heatingorsystemtypeid           34145
# lotsizesquarefeet               10136
# poolcnt                         72274
# poolsizesum                     89184
# pooltypeid10                    88991
# pooltypeid2                     88946
# ...

# %% [markdown]
# Lots of missing value for multiple columns in the dataset. 1168 rows account for 100% of the data. So, in order to avoid generating synthetic data for columns which have more than 60% missing values, I will drop those columns and perform feature engineering on the rest of the data.

# %% [markdown]
# #### Dropping columns having > 60% missing values:

# %%
def drop_cols_with_max_missing_values(df):
    mis_val = [var for var in final_df.columns if final_df[var].isnull().sum()>0]
    final_df[mis_val].isnull().sum()
    
    limit = np.abs((df.shape[0] * 0.6))
    var_dropping = [var for var in mis_val if final_df[var].isnull().sum() > limit]
    print('Columns with more than 60% missing values: \n\n', var_dropping)
    
    final_df.drop(columns=var_dropping, axis=1, inplace=True)
    return final_df

final_df = drop_cols_with_max_missing_values(final_df)
# Out:
# Columns with more than 60% missing values:
#
#  ['airconditioningtypeid', 'architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedfloor1squarefeet', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6', 'fireplacecnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'regionidneighborhood', 'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid', 'yardbuildingsqft17', 'yardbuildingsqft26', 'numberofstories', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear']

# %%
final_df.shape
# Out:
# (90150, 31)

# %%
final_df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#      fips  fullbathcnt  heatingorsystemtypeid    latitude    longitude  \
# 0  6111.0          2.0                    NaN  34303597.0 -119287236.0
# ...

# %%
final_df['yeardifference'] = final_df['assessmentyear'] - final_df['yearbuilt']
final_df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#      fips  fullbathcnt  heatingorsystemtypeid    latitude    longitude  \
# 0  6111.0          2.0                    NaN  34303597.0 -119287236.0
# ...

# %%
final_df.drop(columns=['assessmentyear', 'yearbuilt', 'transactiondate'], axis=1, inplace=True)
final_df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#      fips  fullbathcnt  heatingorsystemtypeid    latitude    longitude  \
# 0  6111.0          2.0                    NaN  34303597.0 -119287236.0
# ...

# %%
final_df.shape
# Out:
# (90150, 29)

# %% [markdown]
# ### Transform Incorrectly Scaled Variables
#
# As mentioned in the data dictionary, the latitude and longitude has been multiplied to 10^6. So I will perform a division of the same to scale it to original. I will perform a similar operation for 'rawcensustractandblock'. Finally, I will perform a division of 10^12 for the 'censustractandblock' variable to bring it to original scale.

# %%
final_df[['latitude', 'longitude']] = (final_df[['latitude', 'longitude']])/(10**6)
final_df['censustractandblock'] = (final_df['censustractandblock'])/(10**12)
final_df['rawcensustractandblock'] = (final_df['rawcensustractandblock'])/(10**6)

final_df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#      fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# 0  6111.0          2.0                    NaN  34.303597 -119.287236
# ...

# %% [markdown]
# ### Handling missing values

# %%
def replace_missing_data(df, mis_vars):
    for var in mis_vars:
        final_df[var] = final_df[var].fillna(final_df[var].mode()[0])
    return df

mis_var = [var for var in final_df.columns if final_df[var].isnull().sum() > 0]
final_df = replace_missing_data(final_df, mis_var)

# %%
final_df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# heatingorsystemtypeid           0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# propertylandusetypeid           0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# ...

# %% [markdown]
# ### Encoding Categorical Variables

# %%
cat = final_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['propertycountylandusecode', 'propertyzoningdesc'], dtype='object')

# %%
cat_vars = [var for var in final_df.columns if final_df[var].dtypes=='O']
cat_vars
# Out:
# ['propertycountylandusecode', 'propertyzoningdesc']

# %%
def encode_categorical_variables(df, cat_vars):
    for i in range(len(cat_vars)):
        var = cat_vars[i]
        var_le = LabelEncoder()
        var_labels = var_le.fit_transform(final_df[var])
        var_mappings = {index: label for index, label in enumerate(var_le.classes_)}
        final_df[(var + '_labels')] = var_labels
        
        # dropping the original column since it has already been encoded
        final_df.drop(columns=var, axis=1, inplace=True)
        
    return final_df

final_df = encode_categorical_variables(final_df, cat_vars)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90150 entries, 0 to 90274
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   parcelid                          90150 non-null  int64
#  1   bathroomcnt                       90150 non-null  float64
#  2   bedroomcnt                        90150 non-null  float64
#  3   buildingqualitytypeid             90150 non-null  float64
#  4   calculatedbathnbr                 90150 non-null  float64
#  5   calculatedfinishedsquarefeet      90150 non-null  float64
#  6   finishedsquarefeet12              90150 non-null  float64
#  7   fips                              90150 non-null  float64
#  8   fullbathcnt                       90150 non-null  float64
#  9   heatingorsystemtypeid             90150 non-null  float64
#  10  latitude                          90150 non-null  float64
# ...

# %%
final_df.head(10)
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    7.0
# 1  17088994          1.0         2.0                    7.0
# 2  17100444          2.0         3.0                    7.0
# 3  17102429          1.5         2.0                    7.0
# 4  17109604          2.5         4.0                    7.0
# 5  17125829          2.5         4.0                    7.0
# 6  17132911          2.0         3.0                    7.0
# 7  17134926          2.5         5.0                    7.0
# 8  17139988          2.0         3.0                    7.0
# 9  17167359          1.0         3.0                    7.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# ...

# %%
final_df.tail()
# Out:
#        parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 90270  11876798          3.0         4.0                    4.0
# 90271  12808516          2.0         3.0                    7.0
# 90272  12010248          2.0         2.0                    4.0
# 90273  14310905          2.5         3.0                    7.0
# 90274  14636609          2.5         3.0                    7.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 90270                3.0                        2068.0                2068.0
# 90271                2.0                        1352.0                1352.0
# 90272                2.0                         860.0                 860.0
# 90273                2.5                        2268.0                2268.0
# 90274                2.5                        1812.0                1812.0
#
#          fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# ...

# %%
final_df.shape
# Out:
# (90150, 29)

# %%
# Checking & Removing Outliers: 
z = np.abs(stats.zscore(final_df))

# for all the values that z-score is less than 3, the data should be kept and the others will be discarded
no_out_df = final_df[(z < 3).all(axis=1)]
no_out_df.shape
# Out:
# (70260, 29)

# %%
no_out_df.corr()
# Out:
#                                   parcelid  bathroomcnt  bedroomcnt  \
# parcelid                          1.000000     0.028423    0.014068
# bathroomcnt                       0.028423     1.000000    0.576233
# bedroomcnt                        0.014068     0.576233    1.000000
# buildingqualitytypeid             0.427057    -0.302725   -0.093848
# calculatedbathnbr                 0.032116     0.977620    0.536776
# calculatedfinishedsquarefeet      0.046356     0.723948    0.658793
# finishedsquarefeet12              0.050844     0.717572    0.646947
# fips                              0.875261     0.096319    0.062177
# fullbathcnt                      -0.071773     0.954987    0.528829
# heatingorsystemtypeid            -0.197104    -0.421220   -0.146429
# latitude                         -0.799259     0.025654    0.067254
# longitude                         0.870357     0.033585    0.055389
# lotsizesquarefeet                -0.206629     0.022510   -0.182343
# ...

# %%
# Heatmap
corr_matrix = no_out_df.corr()
fig, ax = plt.subplots(figsize=(25,15))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt=".2f",
                cmap="YlGnBu");

bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5);

# %% [markdown]
# We observe high correlation among some of the feature variables from the above correlation plot. Hence we will drop some of the features.

# %%
no_out_df.drop(columns=['calculatedbathnbr', 'calculatedfinishedsquarefeet', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'fullbathcnt'], axis=1, inplace=True)

corr_matrix = no_out_df.corr()
fig, ax = plt.subplots(figsize=(25,15))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt=".2f",
                cmap="YlGnBu");

bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5);

# %%
no_out_df.shape
# Out:
# (70260, 23)

# %%
no_out_df.head()
# Out:
#     parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 26  10726315          3.0         3.0                    4.0
# 27  10727091          2.0         3.0                    7.0
# 28  10730788          2.0         4.0                    7.0
# 29  10735394          3.0         4.0                    4.0
# 31  10743512          3.0         2.0                    4.0
#
#     finishedsquarefeet12    fips  heatingorsystemtypeid   latitude  \
# 26                2445.0  6037.0                    2.0  34.184300
# 27                1160.0  6037.0                    2.0  34.188121
# 28                1570.0  6037.0                    2.0  34.188446
# 29                2863.0  6037.0                    2.0  34.171439
# 31                1394.0  6037.0                    2.0  34.152890
#
#      longitude  lotsizesquarefeet  propertylandusetypeid  \
# 26 -118.657000            63878.0                  266.0
# 27 -118.646361             7688.0                  261.0
# ...

# %% [markdown]
# * Due to repetitive data, we will drop 1 of rawcensustractandblock or censustractandblock.
# * The propertycountylandusecode_labels will serve no useful purpose for our model prediction, hence we will drop it.
# * parcelid filed will also server no use for prediction, hence we will drop this but after doing the train_test_split to keep the labels for predictions

# %%
no_out_df.drop(columns=['censustractandblock', 'propertycountylandusecode_labels'], axis=1, inplace=True)
no_out_df.shape
# Out:
# (70260, 21)

# %% [markdown]
# ## ML Model

# %%
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso, SGDRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV, cross_val_score
import xgboost

# %%
no_out_df.head()
# Out:
#     parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 26  10726315          3.0         3.0                    4.0
# 27  10727091          2.0         3.0                    7.0
# 28  10730788          2.0         4.0                    7.0
# 29  10735394          3.0         4.0                    4.0
# 31  10743512          3.0         2.0                    4.0
#
#     finishedsquarefeet12    fips  heatingorsystemtypeid   latitude  \
# 26                2445.0  6037.0                    2.0  34.184300
# 27                1160.0  6037.0                    2.0  34.188121
# 28                1570.0  6037.0                    2.0  34.188446
# 29                2863.0  6037.0                    2.0  34.171439
# 31                1394.0  6037.0                    2.0  34.152890
#
#      longitude  lotsizesquarefeet  propertylandusetypeid  \
# 26 -118.657000            63878.0                  266.0
# 27 -118.646361             7688.0                  261.0
# ...

# %%
df = no_out_df.copy()

# Splitting the dataset into train & test
X = df.drop("logerror", axis=1)
y = df["logerror"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X.shape, y.shape
# Out:
# ((70260, 20), (70260,))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((52695, 20), (52695,), (17565, 20), (17565,))

# %%
# feature scaling

train_vars = [var for var in X_train.columns if var not in ['parcelid', 'logerror']]

sc = StandardScaler()
sc.fit(X_train[train_vars])

X_train[train_vars] = sc.transform(X_train[train_vars])
X_test[train_vars] = sc.transform(X_test[train_vars])

# %%
X_train.head()
# Out:
#        parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 37028  11187728    -0.195309    0.062287              -1.456510
# 86015  13100698    -0.195309    0.062287              -1.456510
# 88632  12041180    -0.195309    1.078143               0.627901
# 12796  12020480    -0.195309   -0.953568              -1.456510
# 85841  11497751     1.046236    1.078143               0.627901
#
#        finishedsquarefeet12      fips  heatingorsystemtypeid  latitude  \
# 37028             -0.636226 -0.673033              -0.528815  2.231653
# 86015             -0.621152 -0.673033              -0.528815 -0.008027
# 88632              0.664632 -0.673033               1.913506  0.928204
# 12796              0.432497 -0.673033              -0.528815  0.421906
# 85841              0.884708 -0.673033               1.913506 -0.380465
#
#        longitude  lotsizesquarefeet  propertylandusetypeid  \
# 37028  -0.142916          -0.283489              -0.500769
# ...

# %%
X_train_new = X_train.copy()
X_test_new = X_test.copy()

# Dropping parcelid
X_train.drop(columns='parcelid', axis=1, inplace=True)
X_test.drop(columns='parcelid', axis=1, inplace=True)

# %% [markdown]
# ### Linear Regression Model

# %%
np.random.seed(42)
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
linear_reg_pred = linear_reg.predict(X_test)

mae = mean_absolute_error(y_test, linear_reg_pred)
mse = mean_squared_error(y_test, linear_reg_pred)
rmse = sqrt(mean_squared_error(y_test, linear_reg_pred))

print('Mean Absolute Error : {}'.format(mae))
print()
print('Mean Squared Error : {}'.format(mse))
print()
print('Root Mean Squared Error : {}'.format(rmse))
# Out:
# Mean Absolute Error : 0.05295414628841447
#
# Mean Squared Error : 0.007219345732803016
#
# Root Mean Squared Error : 0.0849667330948002

# %%
results = pd.DataFrame([['Linear Regression', mae, mse, rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])
results
# Out:
#                Model       MAE       MSE      RMSE
# 0  Linear Regression  0.052954  0.007219  0.084967

# %% [markdown]
# ### Elastic Net Model

# %%
np.random.seed(42)
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X_train, y_train)
elastic_net_pred = elastic_net.predict(X_test)

elastic_mae = mean_absolute_error(y_test, elastic_net_pred)
elastic_mse = mean_squared_error(y_test, elastic_net_pred)
elastic_rmse = sqrt(mean_squared_error(y_test, elastic_net_pred))

print('Mean Absolute Error : {}'.format(elastic_mae))
print()
print('Mean Squared Error : {}'.format(elastic_mse))
print()
print('Root Mean Squared Error : {}'.format(elastic_rmse))
# Out:
# Mean Absolute Error : 0.05298228211735857
#
# Mean Squared Error : 0.007283835511516615
#
# Root Mean Squared Error : 0.08534538951529025

# %%
model_results = pd.DataFrame([['Elastic Net', elastic_mae, elastic_mse, elastic_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(model_results, ignore_index=True)
results
# Out:
#                Model       MAE       MSE      RMSE
# 0  Linear Regression  0.052954  0.007219  0.084967
# 1        Elastic Net  0.052982  0.007284  0.085345

# %% [markdown]
# ### Ridge Regression Model

# %%
np.random.seed(42)
ridge_reg = Ridge(alpha=1, solver='cholesky')
ridge_reg.fit(X_train, y_train)
ridge_reg_pred = ridge_reg.predict(X_test)

ridge_mae = mean_absolute_error(y_test, ridge_reg_pred)
ridge_mse = mean_squared_error(y_test, ridge_reg_pred)
ridge_rmse = sqrt(mean_squared_error(y_test, ridge_reg_pred))

print('Mean Absolute Error : {}'.format(ridge_mae))
print()
print('Mean Squared Error : {}'.format(ridge_mse))
print()
print('Root Mean Squared Error : {}'.format(ridge_rmse))
# Out:
# Mean Absolute Error : 0.05295498846921726
#
# Mean Squared Error : 0.0072190140460197515
#
# Root Mean Squared Error : 0.0849647812097445

# %%
ridge_results = pd.DataFrame([['Ridge Regression', ridge_mae, ridge_mse, ridge_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(ridge_results, ignore_index=True)
results
# Out:
#                Model       MAE       MSE      RMSE
# 0  Linear Regression  0.052954  0.007219  0.084967
# 1        Elastic Net  0.052982  0.007284  0.085345
# 2   Ridge Regression  0.052955  0.007219  0.084965

# %% [markdown]
# ### Lasso Regression Model

# %%
lasso_reg = Lasso(alpha=0.1, random_state=42)
lasso_reg.fit(X_train, y_train)
lasso_reg_pred = lasso_reg.predict(X_test)

lasso_mae = mean_absolute_error(y_test, lasso_reg_pred)
lasso_mse = mean_squared_error(y_test, lasso_reg_pred)
lasso_rmse = sqrt(mean_squared_error(y_test, lasso_reg_pred))

print('Mean Absolute Error : {}'.format(lasso_mae))
print()
print('Mean Squared Error : {}'.format(lasso_mse))
print()
print('Root Mean Squared Error : {}'.format(lasso_rmse))
# Out:
# Mean Absolute Error : 0.05298228211735857
#
# Mean Squared Error : 0.007283835511516615
#
# Root Mean Squared Error : 0.08534538951529025

# %%
lasso_results = pd.DataFrame([['Lasso Regression', lasso_mae, lasso_mse, lasso_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(lasso_results, ignore_index=True)
results
# Out:
#                Model       MAE       MSE      RMSE
# 0  Linear Regression  0.052954  0.007219  0.084967
# 1        Elastic Net  0.052982  0.007284  0.085345
# 2   Ridge Regression  0.052955  0.007219  0.084965
# 3   Lasso Regression  0.052982  0.007284  0.085345

# %% [markdown]
# ### XG Boost Regression Model

# %%
xgb_reg = xgboost.XGBRegressor(random_state=42)
xgb_reg.fit(X_train, y_train)
xgb_reg_pred = xgb_reg.predict(X_test)

xgb_mae = mean_absolute_error(y_test, xgb_reg_pred)
xgb_mse = mean_squared_error(y_test, xgb_reg_pred)
xgb_rmse = sqrt(mean_squared_error(y_test, xgb_reg_pred))

print('Mean Absolute Error : {}'.format(xgb_mae))
print()
print('Mean Squared Error : {}'.format(xgb_mse))
print()
print('Root Mean Squared Error : {}'.format(xgb_rmse))
# Out:
# Mean Absolute Error : 0.05392809962208806
#
# Mean Squared Error : 0.007319725173768916
#
# Root Mean Squared Error : 0.08555539242951853

# %%
xgb_results = pd.DataFrame([['XGBoost Regression', xgb_mae, xgb_mse, xgb_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(xgb_results, ignore_index=True)
results
# Out:
#                 Model       MAE       MSE      RMSE
# 0   Linear Regression  0.052954  0.007219  0.084967
# 1         Elastic Net  0.052982  0.007284  0.085345
# 2    Ridge Regression  0.052955  0.007219  0.084965
# 3    Lasso Regression  0.052982  0.007284  0.085345
# 4  XGBoost Regression  0.053928  0.007320  0.085555

# %% [markdown]
# ### Ada Boost Regression Model

# %%
adaboost_reg = AdaBoostRegressor(random_state=42)
adaboost_reg.fit(X_train, y_train)
adaboost_reg_pred = adaboost_reg.predict(X_test)

adaboost_mae = mean_absolute_error(y_test, adaboost_reg_pred)
adaboost_mse = mean_squared_error(y_test, adaboost_reg_pred)
adaboost_rmse = sqrt(mean_squared_error(y_test, adaboost_reg_pred))

print('Mean Absolute Error : {}'.format(adaboost_mae))
print()
print('Mean Squared Error : {}'.format(adaboost_mse))
print()
print('Root Mean Squared Error : {}'.format(adaboost_rmse))
# Out:
# Mean Absolute Error : 0.057417859422094826
#
# Mean Squared Error : 0.007602358106236897
#
# Root Mean Squared Error : 0.08719150248869953

# %%
adaboost_results = pd.DataFrame([['AdaBoost Regression', adaboost_mae, adaboost_mse, adaboost_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(adaboost_results, ignore_index=True)
results
# Out:
#                  Model       MAE       MSE      RMSE
# 0    Linear Regression  0.052954  0.007219  0.084967
# 1          Elastic Net  0.052982  0.007284  0.085345
# 2     Ridge Regression  0.052955  0.007219  0.084965
# 3     Lasso Regression  0.052982  0.007284  0.085345
# 4   XGBoost Regression  0.053928  0.007320  0.085555
# 5  AdaBoost Regression  0.057418  0.007602  0.087192

# %% [markdown]
# ### Gradient Boosting Regression Model

# %%
gb_reg = GradientBoostingRegressor(random_state=42)
gb_reg.fit(X_train, y_train)
gb_reg_pred = gb_reg.predict(X_test)

gb_mae = mean_absolute_error(y_test, gb_reg_pred)
gb_mse = mean_squared_error(y_test, gb_reg_pred)
gb_rmse = sqrt(mean_squared_error(y_test, gb_reg_pred))

print('Mean Absolute Error : {}'.format(gb_mae))
print()
print('Mean Squared Error : {}'.format(gb_mse))
print()
print('Root Mean Squared Error : {}'.format(gb_rmse))
# Out:
# Mean Absolute Error : 0.05284249558400285
#
# Mean Squared Error : 0.007178611433255506
#
# Root Mean Squared Error : 0.0847266866651559

# %%
gb_results = pd.DataFrame([['GradientBoosting Regression', gb_mae, gb_mse, gb_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(gb_results, ignore_index=True)
results
# Out:
#                          Model       MAE       MSE      RMSE
# 0            Linear Regression  0.052954  0.007219  0.084967
# 1                  Elastic Net  0.052982  0.007284  0.085345
# 2             Ridge Regression  0.052955  0.007219  0.084965
# 3             Lasso Regression  0.052982  0.007284  0.085345
# 4           XGBoost Regression  0.053928  0.007320  0.085555
# 5          AdaBoost Regression  0.057418  0.007602  0.087192
# 6  GradientBoosting Regression  0.052842  0.007179  0.084727

# %% [markdown]
# ### Decision Tree Regressor

# %%
tree_reg = DecisionTreeRegressor(max_depth=5, random_state=42)
tree_reg.fit(X_train, y_train)
tree_reg_pred = tree_reg.predict(X_test)

tree_mae = mean_absolute_error(y_test, tree_reg_pred)
tree_mse = mean_squared_error(y_test, tree_reg_pred)
tree_rmse = sqrt(mean_squared_error(y_test, tree_reg_pred))

print('Mean Absolute Error : {}'.format(tree_mae))
print()
print('Mean Squared Error : {}'.format(tree_mse))
print()
print('Root Mean Squared Error : {}'.format(tree_rmse))
# Out:
# Mean Absolute Error : 0.053200570181696015
#
# Mean Squared Error : 0.007268385732497424
#
# Root Mean Squared Error : 0.08525482820636861

# %%
tree_results = pd.DataFrame([['DecisionTree Regressor', tree_mae, tree_mse, tree_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(tree_results, ignore_index=True)
results
# Out:
#                          Model       MAE       MSE      RMSE
# 0            Linear Regression  0.052954  0.007219  0.084967
# 1                  Elastic Net  0.052982  0.007284  0.085345
# 2             Ridge Regression  0.052955  0.007219  0.084965
# 3             Lasso Regression  0.052982  0.007284  0.085345
# 4           XGBoost Regression  0.053928  0.007320  0.085555
# 5          AdaBoost Regression  0.057418  0.007602  0.087192
# 6  GradientBoosting Regression  0.052842  0.007179  0.084727
# 7       DecisionTree Regressor  0.053201  0.007268  0.085255

# %% [markdown]
# ### Random Forest Regression Model

# %%
forest_reg = RandomForestRegressor(n_estimators= 500, max_depth=6, random_state=42)
forest_reg.fit(X_train, y_train)
forest_reg_pred = forest_reg.predict(X_test)

forest_mae = mean_absolute_error(y_test, forest_reg_pred)
forest_mse = mean_squared_error(y_test, forest_reg_pred)
forest_rmse = sqrt(mean_squared_error(y_test, forest_reg_pred))

print('Mean Absolute Error : {}'.format(forest_mae))
print()
print('Mean Squared Error : {}'.format(forest_mse))
print()
print('Root Mean Squared Error : {}'.format(forest_rmse))
# Out:
# Mean Absolute Error : 0.052799235391265374
#
# Mean Squared Error : 0.007190694377137524
#
# Root Mean Squared Error : 0.08479796210486149

# %%
forest_results = pd.DataFrame([['Random Forest Regression', forest_mae, forest_mse, forest_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(forest_results, ignore_index=True)
results
# Out:
#                          Model       MAE       MSE      RMSE
# 0            Linear Regression  0.052954  0.007219  0.084967
# 1                  Elastic Net  0.052982  0.007284  0.085345
# 2             Ridge Regression  0.052955  0.007219  0.084965
# 3             Lasso Regression  0.052982  0.007284  0.085345
# 4           XGBoost Regression  0.053928  0.007320  0.085555
# 5          AdaBoost Regression  0.057418  0.007602  0.087192
# 6  GradientBoosting Regression  0.052842  0.007179  0.084727
# 7       DecisionTree Regressor  0.053201  0.007268  0.085255
# 8     Random Forest Regression  0.052799  0.007191  0.084798

# %% [markdown]
# ### Cross Validation & Hyperparameter Optimization

# %%
scores = cross_val_score(forest_reg, 
                         X_train, 
                         y_train, 
                         scoring="neg_mean_squared_error", 
                         cv = 5)

# %%
forest_reg_rmse_scores = np.sqrt(-scores)
forest_reg_rmse_scores
# Out:
# array([0.08468545, 0.08271553, 0.08619409, 0.0835339 , 0.08429807])

# %%
# Hyperparameter Optimization
np.random.seed(42)

param_grid = [
    {'n_estimators': [300, 400, 500], 'max_features': [2, 4, 6]},
    {'bootstrap': [False], 'n_estimators': [300, 400, 500], 
     'max_features': [2, 4, 6]}
]

forest_regressor = RandomForestRegressor()

grid_search = GridSearchCV(forest_regressor, 
                           param_grid, 
                           scoring = 'neg_mean_squared_error',
                           return_train_score = True,
                           cv=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-231b374c92ba> in <module>
# ----> 1 grid_search.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
grid_search.best_params_

# %%
grid_search.best_estimator_

# %%
final_predictor = grid_search.best_estimator_
final_predictor.fit(X_train, y_train)
final_pred = final_predictor.predict(X_test)

final_mae = mean_absolute_error(y_test, final_pred)
final_mse = mean_squared_error(y_test, final_pred)
final_rmse = sqrt(mean_squared_error(y_test, final_pred))

print('Mean Absolute Error : {}'.format(final_mae))
print()
print('Mean Squared Error : {}'.format(final_mse))
print()
print('Root Mean Squared Error : {}'.format(final_rmse))

# %%
final_results = pd.DataFrame([['RandomForest GridSearchCV', final_mae, final_mse, final_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(final_results, ignore_index=True)
results

# %%
np.random.seed(42)
search_grid={'n_estimators':[500,1000,2000],
             'learning_rate':[.001,0.01,.1],
             'random_state':[1]
            }

ada = AdaBoostRegressor()

ada_search = GridSearchCV(ada, 
                          search_grid, 
                          scoring = 'neg_mean_squared_error', 
                          return_train_score = True, 
                          cv = 5
                         )

ada_search.fit(X_train, y_train)

# %%
ada_search.best_params_

# %%
grid_ada_predictor = ada_search.best_estimator_
grid_ada_predictor.fit(X_train, y_train)
grid_ada_pred = grid_ada_predictor.predict(X_test)

grid_mae = mean_absolute_error(y_test, grid_ada_pred)
grid_mse = mean_squared_error(y_test, grid_ada_pred)
grid_rmse = sqrt(mean_squared_error(y_test, grid_ada_pred))

print('Mean Absolute Error : {}'.format(grid_mae))
print()
print('Mean Squared Error : {}'.format(grid_mse))
print()
print('Root Mean Squared Error : {}'.format(grid_rmse))

# %%
grid_results = pd.DataFrame([['AdaBoost GridSearchCV', grid_mae, grid_mse, grid_rmse]],
                       columns=['Model', 'MAE', 'MSE', 'RMSE'])

results = results.append(grid_results, ignore_index=True)
results

# %%
# Saving predictions
model_pred = pd.DataFrame({'parcelid':X_test_new.parcelid, 'logerror':final_pred})
model_pred.to_csv('model-predictions.csv',index=False)
model_pred.head()
